# %%
#import library
import matplotlib.pyplot as plt

# %%
#first line
dev_x=[12,22,30,50,65]
dev_y=[150,551,330,650,250]


plt.plot(dev_x,dev_y,#color="",linestyle='', marker=''
        )
plt.title("enter title of a head")
plt.xlabel("enter title in x axis ")
plt.ylabel("enter title in y axis ")

#second line
dev_x2=[1,20,35,44,55]
dev_y2=[300,401,500,600,700]

plt.plot(dev_x2,dev_y2)

#show what line of each
plt.legend(["lable of the first","lable of second"])
# save the figure
plt.savefig("")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
