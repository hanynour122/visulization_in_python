# %%
#import library
import matplotlib.pyplot as plt
import numpy as np

# %%
#first line
dev_x=[120,220,300,500,651]
dev_y=[150,551,330,650,250]
x_indecies=np.arange(len(dev_x))

plt.bar(dev_x,dev_y, width=10,#color="",linestyle='',
        )
plt.title("enter title of a head")
plt.xlabel("enter title in x axis ")
plt.ylabel("enter title in y axis ")

#second line
dev_x2=[100,210,315,414,515]
dev_y2=[300,401,500,600,700]

plt.bar(dev_x2,dev_y2,width=10)

#plt.xticks(ticks=x_indecies , labels=dev_x)

#show what line of each
plt.legend(["lable of the first","lable of second"])

# save the figure
plt.savefig("")


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
