# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig=plt.figure()

# %%
fig2, ax1=plt.subplots(nrows=2,ncols=2)

# %%
ax1.hist([1,2,3,4],[1,2,3,4])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4792\1801102248.py in <module>
# ----> 1 ax1.hist([1,2,3,4],[1,2,3,4])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'hist'

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]
ax=fig.add_subplot()
ax.plot(x,y)

# %%
fig
